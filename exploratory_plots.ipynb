# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Benks\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
modern_df = pd.read_csv('.\Datasets\modern_ai.csv')
pre_df2 = pd.read_csv('.\Datasets\pre_ai.csv')

print("Modern AI Dataset Statistics:")
print(modern_df.describe())
print("\nPre AI Dataset Statistics:")
print(pre_df2.describe())
# Out:
# Modern AI Dataset Statistics:
#                  id  conversation_id       timezone  replies_count  \
# count  8.930760e+05     8.930760e+05  893076.000000  893076.000000
# mean   1.040813e+18     1.040717e+18    -407.503057       0.108286
# std    1.496239e+17     1.496439e+17      26.344081       3.580560
# min    8.246196e+17     6.059109e+09    -500.000000       0.000000
# 25%    9.033985e+17     9.033854e+17    -400.000000       0.000000
# 50%    1.012776e+18     1.012763e+18    -400.000000       0.000000
# 75%    1.156422e+18     1.156399e+18    -400.000000       0.000000
# max    1.417273e+18     1.417273e+18    -400.000000    1881.000000
#
#        retweets_count    likes_count          video
# count   893076.000000  893076.000000  893076.000000
# mean         1.678344       2.393616       0.313502
# std         84.509796     248.674498       0.463917
# min          0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       0.000000
# ...

# %%
modern_df.head()
# Out:
#              id  conversation_id               created_at        date  \
# 0  8.265808e+17     8.265808e+17  2017-01-31 18:59:44 EST  2017-01-31
# 1  8.265807e+17     8.265807e+17  2017-01-31 18:59:35 EST  2017-01-31
# 2  8.265806e+17     8.265806e+17  2017-01-31 18:59:14 EST  2017-01-31
# 3  8.265806e+17     8.265806e+17  2017-01-31 18:59:01 EST  2017-01-31
# 4  8.265806e+17     8.265806e+17  2017-01-31 18:59:01 EST  2017-01-31
#
#        time  timezone                                              tweet  \
# 0  18:59:44      -400  What topic could spark human dialogue on AI? A...
# 1  18:59:35      -400  I think #ArtificialIntelligence will augment h...
# 2  18:59:14      -400  What Managers Need to Know About Artificial In...
# 3  18:59:01      -400  4 ways Artificial Intelligence changes the gam...
# 4  18:59:01      -400  Artificial Intelligence can Shape the Future o...
#
#   language                                               urls photos  \
# ...
